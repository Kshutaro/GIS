# %%
import geopandas as gpd
import pandas as pd

# %%
totigi_ku = gpd.read_file('/Users/shu/GIS/week07/N03-23_09_230101.geojson')

# %%
totigi_ku.plot()
# Out:
# <Axes: >

# %%
totigi_pop = pd.read_csv('totigi.csv')

# %%
totigi_pop.head()
# Out:
#      KEY_CODE  HYOSYO CITYNAME  NAME  HTKSYORI  HTKSAKI  GASSAN    人口総数  \
# 0        9201       1     宇都宮市   NaN         0      NaN     NaN  518757
# 1    92010010       2     宇都宮市  明保野町         0      NaN     NaN     259
# 2    92010020       3     宇都宮市     旭         0      NaN     NaN     807
# 3  9201002001       4     宇都宮市  旭一丁目         0      NaN     NaN     415
# 4  9201002002       4     宇都宮市  旭二丁目         0      NaN     NaN     392
#
#         男       女    世帯総数
# 0  259616  259141  230841
# 1     136     123     150
# 2     387     420     389
# 3     184     231     202
# 4     203     189     187

# %%
totigi_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2923 entries, 0 to 2922
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  2923 non-null   int64
#  1   HYOSYO    2923 non-null   int64
#  2   CITYNAME  2923 non-null   object
#  3   NAME      2897 non-null   object
#  4   HTKSYORI  2923 non-null   int64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      2923 non-null   object
#  8   男         2923 non-null   object
#  9   女         2923 non-null   object
#  10  世帯総数      2923 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 251.3+ KB

# %%
totigi_ku.rename(columns={'N03_007':'KEY_CODE'},inplace=True)

# %%
totigi_ku
# Out:
#    N03_001  N03_002 N03_003 N03_004 KEY_CODE  \
# 0      栃木県      NaN     NaN    宇都宮市    09201
# 1      栃木県      NaN     NaN     足利市    09202
# 2      栃木県      NaN     NaN     栃木市    09203
# 3      栃木県      NaN     NaN     佐野市    09204
# 4      栃木県      NaN     NaN     佐野市    09204
# 5      栃木県      NaN     NaN     鹿沼市    09205
# 6      栃木県      NaN     NaN     日光市    09206
# 7      栃木県      NaN     NaN     小山市    09208
# 8      栃木県      NaN     NaN     真岡市    09209
# 9      栃木県      NaN     NaN    大田原市    09210
# 10     栃木県      NaN     NaN     矢板市    09211
# 11     栃木県      NaN     NaN   那須塩原市    09213
# 12     栃木県      NaN     NaN   那須塩原市    09213
# 13     栃木県      NaN     NaN    さくら市    09214
# 14     栃木県      NaN     NaN   那須烏山市    09215
# 15     栃木県      NaN     NaN     下野市    09216
# 16     栃木県      NaN     河内郡    上三川町    09301
# 17     栃木県      NaN     河内郡    上三川町    09301
# 18     栃木県      NaN     芳賀郡     益子町    09342
# 19     栃木県      NaN     芳賀郡     茂木町    09343
# ...

# %%
totigi_ku['KEY_CODE'] = totigi_ku['KEY_CODE'].astype(int)

# %%
totigi_ku_pop = totigi_ku.merge(totigi_pop,on='KEY_CODE')

# %%
totigi_ku_pop
# Out:
#    N03_001  N03_002 N03_003 N03_004  KEY_CODE  \
# 0      栃木県      NaN     NaN    宇都宮市      9201
# 1      栃木県      NaN     NaN     足利市      9202
# 2      栃木県      NaN     NaN     栃木市      9203
# 3      栃木県      NaN     NaN     佐野市      9204
# 4      栃木県      NaN     NaN     佐野市      9204
# 5      栃木県      NaN     NaN     鹿沼市      9205
# 6      栃木県      NaN     NaN     日光市      9206
# 7      栃木県      NaN     NaN     小山市      9208
# 8      栃木県      NaN     NaN     真岡市      9209
# 9      栃木県      NaN     NaN    大田原市      9210
# 10     栃木県      NaN     NaN     矢板市      9211
# 11     栃木県      NaN     NaN   那須塩原市      9213
# 12     栃木県      NaN     NaN   那須塩原市      9213
# 13     栃木県      NaN     NaN    さくら市      9214
# 14     栃木県      NaN     NaN   那須烏山市      9215
# 15     栃木県      NaN     NaN     下野市      9216
# 16     栃木県      NaN     河内郡    上三川町      9301
# 17     栃木県      NaN     河内郡    上三川町      9301
# 18     栃木県      NaN     芳賀郡     益子町      9342
# ...

# %%
totigi_ku_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   28 non-null     object
#  1   N03_002   0 non-null      float64
#  2   N03_003   12 non-null     object
#  3   N03_004   28 non-null     object
#  4   KEY_CODE  28 non-null     int64
#  5   geometry  28 non-null     geometry
#  6   HYOSYO    28 non-null     int64
#  7   CITYNAME  28 non-null     object
#  8   NAME      0 non-null      object
#  9   HTKSYORI  28 non-null     int64
#  10  HTKSAKI   0 non-null      float64
#  11  GASSAN    0 non-null      float64
#  12  人口総数      28 non-null     object
#  13  男         28 non-null     object
#  14  女         28 non-null     object
#  15  世帯総数      28 non-null     object
# dtypes: float64(3), geometry(1), int64(3), object(9)
# memory usage: 3.6+ KB

# %%
totigi_ku_pop['人口総数'] = totigi_ku_pop['人口総数'].astype(int)

# %%
totigi_ku_pop.plot(column='人口総数',legend=True)
# Out:
# <Axes: >
